# %%
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

# %%
import pydataset
from gensim import corpora

# %%
from pydataset import data
quakes = data('quakes')
quakes.head()
quakes.tail()
# Out:
#      lat    long  depth  mag  stations
# 1 -20.42  181.62    562  4.8        41
# 2 -20.62  181.03    650  4.2        15
# 3 -26.00  184.10     42  5.4        43
# 4 -17.97  181.66    626  4.1        19
# 5 -20.42  181.96    649  4.0        11
#         lat    long  depth  mag  stations
# 996  -25.93  179.54    470  4.4        22
# 997  -12.28  167.06    248  4.7        35
# 998  -20.13  184.20    244  4.5        34
# 999  -17.40  187.80     40  4.5        14
# 1000 -21.59  170.56    165  6.0       119

# %%
import flask

# %%
import sklearn

# %%
import gensim

# %%
import numpy
# %timeit numpy.random.normal(size=100)
# Out:
# The slowest run took 8.37 times longer than the fastest. This could mean that an intermediate result is being cached.
# 100000 loops, best of 3: 5.71 µs per loop

# %%
quakes
# Out:
#         lat    long  depth  mag  stations
# 1    -20.42  181.62    562  4.8        41
# 2    -20.62  181.03    650  4.2        15
# 3    -26.00  184.10     42  5.4        43
# 4    -17.97  181.66    626  4.1        19
# 5    -20.42  181.96    649  4.0        11
# 6    -19.68  184.31    195  4.0        12
# 7    -11.70  166.10     82  4.8        43
# 8    -28.11  181.93    194  4.4        15
# 9    -28.74  181.74    211  4.7        35
# 10   -17.47  179.59    622  4.3        19
# 11   -21.44  180.69    583  4.4        13
# 12   -12.26  167.00    249  4.6        16
# 13   -18.54  182.11    554  4.4        19
# 14   -21.00  181.66    600  4.4        10
# 15   -20.70  169.92    139  6.1        94
# 16   -15.94  184.95    306  4.3        11
# 17   -13.64  165.96     50  6.0        83
# 18   -17.83  181.50    590  4.5        21
# 19   -23.50  179.78    570  4.4        13
# 20   -22.63  180.31    598  4.4        18
# 21   -20.84  181.16    576  4.5        17
# ...

# %%
import numpy as np
x = np.array([1,2])
x
# Out:
# array([1, 2])

# %% [markdown]
# isto é mais ou menos o mesmo que o que está de seguida

# %%
w2v ={}
with gzip.open("../../../data/glove/glove.6B.50d.txt.gz", "rt") as lines:
    for line in lines:
        word = line.split()[0]
        values = [ float(x) for x in line.split()[1:] ]
        w2v[word] = np.array(values, dtype=float)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-16-4ca25da2a4fc> in <module>()
#       1 w2v ={}
# ----> 2 with gzip.open("../../../data/glove/glove.6B.50d.txt.gz", "rt") as lines:
#       3     for line in lines:
#       4         word = line.split()[0]
#       5         values = [ float(x) for x in line.split()[1:] ]
#
# NameError: name 'gzip' is not defined

# %%
print(w2v.keys())

# %%
from sklearn.pipeline import Pipeline
from sklearn.ensemble import ExtraTreesClassifier

# %%
import numpy as np
import gzip

with gzip.open("../../data/glove/glove.6B.50d.txt.gz", "rt") as lines:
    w2v = {line.split()[0]: np.array(map(float, line.split()[1:])) for line in lines}

# %%
print(len(w2v))
w2v['king']
# Out:
# 400000
# array(<map object at 0x109878cf8>, dtype=object)

# %%
import gensim

# let X be a list of tokenized texts (i.e. list of lists of tokens)
X= ["Lisbon", "is", "a", "very", "beautiful", "place", "in", "europe"]
model = gensim.models.Word2Vec(X, size=100)
w2v = dict(zip(model.index2word, model.syn0))

# %%
class MeanEmbeddingVectorizer(object):
    def __init__(self, word2vec):
        self.word2vec = word2vec
        # if a text is empty we should return a vector of zeros
        # with the same dimensionality as all the other vectors
        self.dim = len(word2vec.itervalues().next())

    def fit(self, X, y):
        return self

    def transform(self, X):
        return np.array([
            np.mean([self.word2vec[w] for w in words if w in self.word2vec]
                    or [np.zeros(self.dim)], axis=0)
            for words in X
        ])

# %%
class TfidfEmbeddingVectorizer(object):
    def __init__(self, word2vec):
        self.word2vec = word2vec
        self.word2weight = None
        self.dim = len(word2vec.itervalues().next())

    def fit(self, X, y):
        tfidf = TfidfVectorizer(analyzer=lambda x: x)
        tfidf.fit(X)
        # if a word was never seen - it must be at least as infrequent
        # as any of the known words - so the default idf is the max of 
        # known idf's
        max_idf = max(tfidf.idf_)
        self.word2weight = defaultdict(
            lambda: max_idf,
            [(w, tfidf.idf_[i]) for w, i in tfidf.vocabulary_.items()])

        return self

    def transform(self, X):
        return np.array([
                np.mean([self.word2vec[w] * self.word2weight[w]
                         for w in words if w in self.word2vec] or
                        [np.zeros(self.dim)], axis=0)
                for words in X
            ])

# %%
X = [['Berlin', 'London'],
     ['cow', 'cat'],
     ['pink', 'yellow']]
y = ['capitals', 'animals', 'colors']
etree_glove_big.fit(X, y)

# never before seen words!!!
test_X = [['dog'], ['red'], ['Madrid']]

print etree_glove_big.predict(test_X)
# Out:
#   File "<ipython-input-4-e048a94089f3>", line 10
#     print etree_glove_big.predict(test_X)
#                         ^
# SyntaxError: invalid syntax

# %%
import numpy
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-1-d4cdadb62aa7> in <module>()
# ----> 1 import numpy
#
# ImportError: No module named 'numpy'

# %%
import nltk

# %%
import scipy

# %%
import numpy as np

# %%
import
